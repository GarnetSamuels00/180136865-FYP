# %% [markdown]
# For a more complex data set it may need to be split multiple times to come up with the decision boundaries
# This is different in comparison to a simple data set where ridge regression can be used to draw when line for the decision boundaries
# The order which the decsion tree is split up is important
# The order which the data sets attributes are selected will affect performance
# To select the ordering system -
# You want an ordering to get a pure subset that gives the lowest entropy (the measure of randomness in the sample)
# For example splitting the teams that average over a certain amount of points into groups. There may be a group that averages over a certain amount of points that always win their games. 1:3 or 6:2 win vs losses for the teams in hypothetical groups is relatively low entropy. This is low Entropy. Having a 50/50 split means there is a high entropy and the entopy is 1 total randomness. When teams are split up into groups based off of attributes you want the majority of the results to either be that the team wins or loses.
# With an ordering system that achieves low entropy there is a High Information Gain
# With an ordering system that achieves high entropy there is a Low Information Gain
# Using an approach that leads to high information gain at every decision split
# Gini Impurity
# Where after splitting a sample ( putting a line at the midpoint for example there may be majority wins at the top and majority losses at the bottom but there might be one data point where ther is a win at the bottom) there wil be an anomalous data point. The decision split is almost pure but there is a little bit of impurity. Similar to entropy. Mathematics

# %%
import pandas as pd 
games = pd.read_csv("nba_games.csv", index_col=0)
games = games.reset_index(drop = True)
games = games.sort_values("date")
games = games.reset_index(drop = True)
games
# Out:
#         mp  mp.1  fg  fga    fg%  3p  3pa    3p%  ft  fta  ...  tov%_max_opp  \
# 0      240   240  33   87  0.379   5   16  0.313  22   29  ...          36.8
# 1      240   240  43   92  0.467   8   26  0.308   9   10  ...          33.3
# 2      240   240  36   91  0.396  15   33  0.455  17   18  ...          31.7
# 3      240   240  31   84  0.369   6   19  0.316  13   17  ...          50.0
# 4      240   240  34   85  0.400  10   32  0.313  16   18  ...          43.6
# ...    ...   ...  ..  ...    ...  ..  ...    ...  ..  ...  ...           ...
# 17767  240   240  43   97  0.443  16   38  0.421  19   21  ...          16.8
# 17768  240   240  47   85  0.553  19   41  0.463  26   30  ...          26.2
# 17769  240   240  36  102  0.353  12   42  0.286  22   27  ...          24.0
# 17770  240   240  41  100  0.410  11   35  0.314  15   16  ...          37.5
# 17771  240   240  35   86  0.407  12   27  0.444  26   30  ...          50.0
#
# ...

# %%
del games["mp.1"]
del games["mp_opp.1"]
del games["index_opp"]

# %%
games
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  tov%_max_opp  \
# 0      240  33   87  0.379   5   16  0.313  22   29  0.759  ...          36.8
# 1      240  43   92  0.467   8   26  0.308   9   10  0.900  ...          33.3
# 2      240  36   91  0.396  15   33  0.455  17   18  0.944  ...          31.7
# 3      240  31   84  0.369   6   19  0.316  13   17  0.765  ...          50.0
# 4      240  34   85  0.400  10   32  0.313  16   18  0.889  ...          43.6
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...           ...
# 17767  240  43   97  0.443  16   38  0.421  19   21  0.905  ...          16.8
# 17768  240  47   85  0.553  19   41  0.463  26   30  0.867  ...          26.2
# 17769  240  36  102  0.353  12   42  0.286  22   27  0.815  ...          24.0
# 17770  240  41  100  0.410  11   35  0.314  15   16  0.938  ...          37.5
# 17771  240  35   86  0.407  12   27  0.444  26   30  0.867  ...          50.0
#
# ...

# %%
def get_target(team):
    team["target"] = team["won"].shift(-1)
    return team

games = games.groupby("team", group_keys=False).apply(get_target)

# %%
games[games["team"] =="LAL"]
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  usg%_max_opp  \
# 0      240  33   87  0.379   5   16  0.313  22   29  0.759  ...          40.4
# 14     240  37   92  0.402  15   32  0.469  25   31  0.806  ...          41.0
# 25     240  34   76  0.447   8   26  0.308  20   29  0.690  ...          30.1
# 40     240  43   90  0.478   7   28  0.250  24   34  0.706  ...          39.1
# 65     240  41  101  0.406  14   33  0.424  13   16  0.813  ...          31.8
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...           ...
# 17636  240  45   91  0.495  12   26  0.462  11   14  0.786  ...          28.8
# 17647  240  43   84  0.512  10   17  0.588  18   24  0.750  ...          32.6
# 17665  240  39   96  0.406   9   31  0.290   8   13  0.615  ...          28.4
# 17697  290  53  105  0.505  10   25  0.400  26   37  0.703  ...          32.1
# 17768  240  47   85  0.553  19   41  0.463  26   30  0.867  ...          31.1
#
# ...

# %%
games["team"]
# Out:
# 0        LAL
# 1        WAS
# 2        TOR
# 3        NYK
# 4        CHO
#         ...
# 17767    ATL
# 17768    LAL
# 17769    POR
# 17770    PHO
# 17771    CHI
# Name: team, Length: 17772, dtype: object

# %%
games["target"][pd.isnull(games["target"])] = 2
# Out:
# C:\Users\Garnet\AppData\Local\Temp\ipykernel_16320\1495898042.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games["target"][pd.isnull(games["target"])] = 2

# %%
games["target"] = games["target"].astype(int, errors="ignore")

# %%
games
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  usg%_max_opp  \
# 0      240  33   87  0.379   5   16  0.313  22   29  0.759  ...          40.4
# 1      240  43   92  0.467   8   26  0.308   9   10  0.900  ...          44.9
# 2      240  36   91  0.396  15   33  0.455  17   18  0.944  ...          30.6
# 3      240  31   84  0.369   6   19  0.316  13   17  0.765  ...          42.7
# 4      240  34   85  0.400  10   32  0.313  16   18  0.889  ...          25.8
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...           ...
# 17767  240  43   97  0.443  16   38  0.421  19   21  0.905  ...          36.4
# 17768  240  47   85  0.553  19   41  0.463  26   30  0.867  ...          31.1
# 17769  240  36  102  0.353  12   42  0.286  22   27  0.815  ...          46.7
# 17770  240  41  100  0.410  11   35  0.314  15   16  0.938  ...          34.3
# 17771  240  35   86  0.407  12   27  0.444  26   30  0.867  ...          50.2
#
# ...

# %%
games["won"].value_counts()
# Out:
# True     8886
# False    8886
# Name: won, dtype: int64

# %%
games["target"].value_counts()
# Out:
# 1    8872
# 0    8870
# 2      30
# Name: target, dtype: int64

# %%
nulls = pd.isnull(games)
nulls = nulls.sum()
nulls = nulls[nulls > 0]
nulls
# Out:
# +/-             17772
# mp_max          17772
# mp_max.1        17772
# +/-_opp         17772
# mp_max_opp      17772
# mp_max_opp.1    17772
# dtype: int64

# %%
valid_columns = games.columns[~games.columns.isin(nulls.index)]
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)

# %%
games = games[valid_columns].copy()
games
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  usg%_max_opp  \
# 0      240  33   87  0.379   5   16  0.313  22   29  0.759  ...          40.4
# 1      240  43   92  0.467   8   26  0.308   9   10  0.900  ...          44.9
# 2      240  36   91  0.396  15   33  0.455  17   18  0.944  ...          30.6
# 3      240  31   84  0.369   6   19  0.316  13   17  0.765  ...          42.7
# 4      240  34   85  0.400  10   32  0.313  16   18  0.889  ...          25.8
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...           ...
# 17767  240  43   97  0.443  16   38  0.421  19   21  0.905  ...          36.4
# 17768  240  47   85  0.553  19   41  0.463  26   30  0.867  ...          31.1
# 17769  240  36  102  0.353  12   42  0.286  22   27  0.815  ...          46.7
# 17770  240  41  100  0.410  11   35  0.314  15   16  0.938  ...          34.3
# 17771  240  35   86  0.407  12   27  0.444  26   30  0.867  ...          50.2
#
# ...

# %%
#splitting the data into just the targets column and all the other columns
#inputs = games.drop('target',axis='columns')
#target = games["target"]

# %%
#inputs

# %%
#target

# %%
games ["venue_code"] = games["home"].astype("category").cat.codes

# %%
games ["opp_code"] = games["team_opp"].astype("category").cat.codes

# %%
games['date'] = pd.to_datetime(games['date'])
# Out:
# C:\Users\Garnet\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/01/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Garnet\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/01/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\Garnet\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/01/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
games ["day_code"] = games ["date"].dt.dayofweek

# %%
games
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  team_opp  \
# 0      240  33   87  0.379   5   16  0.313  22   29  0.759  ...       PHI
# 1      240  43   92  0.467   8   26  0.308   9   10  0.900  ...       ORL
# 2      240  36   91  0.396  15   33  0.455  17   18  0.944  ...       CHO
# 3      240  31   84  0.369   6   19  0.316  13   17  0.765  ...       CHI
# 4      240  34   85  0.400  10   32  0.313  16   18  0.889  ...       TOR
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 17767  240  43   97  0.443  16   38  0.421  19   21  0.905  ...       CLE
# 17768  240  47   85  0.553  19   41  0.463  26   30  0.867  ...       POR
# 17769  240  36  102  0.353  12   42  0.286  22   27  0.815  ...       LAL
# 17770  240  41  100  0.410  11   35  0.314  15   16  0.938  ...       BOS
# 17771  240  35   86  0.407  12   27  0.444  26   30  0.867  ...       IND
#
#        total_opp  home_opp  season       date    won  target  venue_code  \
# ...

# %%
#Due to machine learning algorithms like this decision tree only working on numbers and not Labels
#to turn the team and team_opp columns into numbers the LabelEncoder can be used 
from sklearn.preprocessing import LabelEncoder

# %%
#creating an object of the label encoder class for the column team
#team_code = LabelEncoder()
#creating an object of the label encoder class for the column team
#team_opp_code = LabelEncoder()

# %%
#creating new columns
#inputs['team_code'] = team_code.fit_transform(inputs['team'])
#inputs['team_opp_code'] = team_opp_code.fit_transform(inputs['team_opp'])
#inputs.head()

# %%
#inputs.head()

# %%
#dropping the columns with the team and opponent teams labels 
#inputs_n = inputs.drop(['team','team_opp','date'], axis='columns')
#inputs_n

# %%
#training the classifier 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
clf = DecisionTreeClassifier(max_leaf_nodes=3, random_state=1)

# %%
#predictors = ["venue_code","opp_code","day_code"]

# %%
#the same data set for training and testing are used
#find out how to split up training and testing data set
#model.score(inputs_n,target)

# %%
#model.predict([[inputs]])

# %%
##X_train, X_test, y_trainy_test = train_test_split(inputs_n.drop('targets',axis=1), inputs_n['targets'], test_size=0.2)

# %%
#this splits the data into training and testing sets
predictors = ["venue_code","opp_code","day_code"]
X_train = games[games["date"]<'2022-01-01']
y_train = games[games["date"]<'2022-01-01']
X_test = games[games["date"]>'2022-01-01']
y_test = games[games["date"]>'2022-01-01']

# %%
clf.fit(X_train[predictors], y_train["target"])
# Out:
# DecisionTreeClassifier(max_leaf_nodes=3, random_state=1)

# %%
preds=clf.predict(X_test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(X_test["target"], preds)

# %%
acc
# Out:
# 0.5006329113924051

# %%
combined = pd.DataFrame(dict(actual=X_test["target"], prediction=preds))

# %%
pd.crosstab(index= combined["actual"],columns=combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           405  404
# 1           385  386

# %% [markdown]
# 405 times the model was correct and 404 times the model was wrong
# 386 times the model was correct and 385 times the model was wrong

# %%
from sklearn.metrics import precision_score

# %%
precision_score(X_test["target"], preds)
# Out:
# 0.48860759493670886

# %% [markdown]
# When a win was predicted the team won 48.86% of the time which is below 50%

# %% [markdown]
# # Improvement of the model
# ##### Rolling averages by splitting the data set up into team
# ###### The folloing data groups the data set into team statistics

# %%
grouped_games = games.groupby("team")
group = grouped_games.get_group("GSW")
group
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  team_opp  \
# 54     240  31   79  0.392   7   35  0.200  29   33  0.879  ...       POR
# 76     240  46   86  0.535  17   32  0.531  14   21  0.667  ...       UTA
# 97     240  47   96  0.490  21   48  0.438  11   14  0.786  ...       CHO
# 147    240  48   90  0.533  18   35  0.514  17   19  0.895  ...       CLE
# 187    240  43   96  0.448  20   46  0.435  18   18  1.000  ...       SAS
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 17621  240  46   84  0.548  17   30  0.567  25   35  0.714  ...       NOP
# 17642  240  47   89  0.528  16   32  0.500  21   30  0.700  ...       NOP
# 17679  240  43   84  0.512  11   23  0.478  17   27  0.630  ...       HOU
# 17712  240  46   84  0.548  14   28  0.500  26   32  0.813  ...       PHO
# 17727  265  44   96  0.458  12   27  0.444  13   18  0.722  ...       SAS
#
#        total_opp  home_opp  season       date    won  target  venue_code  \
# ...

# %% [markdown]
# The games of GSW (Golden State Warriors)if the prediction is on the fourth game the model should look at the previous three games to help make better predictions. For example if the team is on a losing streak or a winning streak

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    #closed = ''left' only have the rolling averages of the previous weeks not the week we are trying to calculate for
    rolling_stats = group[cols].rolling(3,closed='left').mean()
    group[new_cols] = rolling_stats
    #removes all of the rows that have missing values 
    group = group.dropna(subset= new_cols)
    return group

# %% [markdown]
# Using the same roling averages as the ones used for Random Forest

# %%
#The same cols are used for the rolling average to keep the inputs consistent 
cols = ["fg","3p","ft","ast","stl","blk","tov", "pts"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['fg_rolling',
#  '3p_rolling',
#  'ft_rolling',
#  'ast_rolling',
#  'stl_rolling',
#  'blk_rolling',
#  'tov_rolling',
#  'pts_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#        mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  opp_code  \
# 3100  240  35   73  0.479  16   30  0.533  26   36  0.722  ...        27
# 3672  240  46   93  0.495  17   37  0.459  10   18  0.556  ...         7
# 3735  240  44   86  0.512  14   33  0.424  12   23  0.522  ...         2
# 4229  240  38   92  0.413   8   39  0.205  19   22  0.864  ...        25
# 4953  240  52   95  0.547  16   35  0.457  11   15  0.733  ...        11
# ...   ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 6097  240  40   91  0.440  15   43  0.349  12   15  0.800  ...         1
# 6372  240  35   82  0.427  13   36  0.361  25   29  0.862  ...        14
# 6697  240  36   80  0.450  14   39  0.359   9   13  0.692  ...        14
# 7086  240  40   90  0.444  12   38  0.316  25   34  0.735  ...        13
# 7173  240  45   93  0.484  18   45  0.400  14   15  0.933  ...        16
#
#       day_code  fg_rolling  3p_rolling  ft_rolling  ast_rolling  stl_rolling  \
# ...

# %% [markdown]
# After getting the original nba_games data Frame and grouped by teams which creates one data frame for each team in the data. Then the lambda function was applied to compute the rolling averages.

# %%
games_rolling = games.groupby("team").apply(lambda x:rolling_averages(x, cols, new_cols))

# %% [markdown]
# ###### Rolling averages are taken from the entire data set

# %%
games_rolling
# Out:
#             mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  opp_code  \
# team                                                            ...
# ATL  2383  240  37   76  0.487   8   22  0.364  19   24  0.792  ...         2
#      2462  240  37   74  0.500  10   26  0.385  16   20  0.800  ...        13
#      3659  240  41   77  0.532   9   21  0.429  30   35  0.857  ...        18
#      4228  240  43   92  0.467  13   33  0.394  15   15  1.000  ...        29
#      5486  240  44   86  0.512  13   31  0.419   6    7  0.857  ...        17
# ...        ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# WAS  6378  240  47   87  0.540  11   33  0.333  17   23  0.739  ...        20
#      6587  240  39   85  0.459   9   27  0.333  22   33  0.667  ...        13
#      6991  240  43   82  0.524  10   31  0.323  16   21  0.762  ...        21
#      7087  240  41   88  0.466  13   38  0.342  15   21  0.714  ...        25
# ...

# %% [markdown]
# Dropping the team name as a seperate level in the pandas index. for a multi level index you would need to use two values to access each row which was not needed

# %%
games_rolling = games_rolling.droplevel('team')

# %%
games_rolling
# Out:
#        mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  opp_code  \
# 2383  240  37   76  0.487   8   22  0.364  19   24  0.792  ...         2
# 2462  240  37   74  0.500  10   26  0.385  16   20  0.800  ...        13
# 3659  240  41   77  0.532   9   21  0.429  30   35  0.857  ...        18
# 4228  240  43   92  0.467  13   33  0.394  15   15  1.000  ...        29
# 5486  240  44   86  0.512  13   31  0.419   6    7  0.857  ...        17
# ...   ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 6378  240  47   87  0.540  11   33  0.333  17   23  0.739  ...        20
# 6587  240  39   85  0.459   9   27  0.333  22   33  0.667  ...        13
# 6991  240  43   82  0.524  10   31  0.323  16   21  0.762  ...        21
# 7087  240  41   88  0.466  13   38  0.342  15   21  0.714  ...        25
# 7179  240  39   83  0.470  14   34  0.412  26   27  0.963  ...        24
#
#       day_code  fg_rolling  3p_rolling  ft_rolling  ast_rolling  stl_rolling  \
# ...

# %%
games_rolling.index = range(games_rolling.shape[0])

# %%
games_rolling
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  opp_code  \
# 0      240  37   76  0.487   8   22  0.364  19   24  0.792  ...         2
# 1      240  37   74  0.500  10   26  0.385  16   20  0.800  ...        13
# 2      240  41   77  0.532   9   21  0.429  30   35  0.857  ...        18
# 3      240  43   92  0.467  13   33  0.394  15   15  1.000  ...        29
# 4      240  44   86  0.512  13   31  0.419   6    7  0.857  ...        17
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...       ...
# 17677  240  47   87  0.540  11   33  0.333  17   23  0.739  ...        20
# 17678  240  39   85  0.459   9   27  0.333  22   33  0.667  ...        13
# 17679  240  43   82  0.524  10   31  0.323  16   21  0.762  ...        21
# 17680  240  41   88  0.466  13   38  0.342  15   21  0.714  ...        25
# 17681  240  39   83  0.470  14   34  0.412  26   27  0.963  ...        24
#
#        day_code  fg_rolling  3p_rolling  ft_rolling  ast_rolling  stl_rolling  \
# ...

# %%
def make_predictions(data,predictors):
    X_train = data[data["date"]<'2022-01-01']
    y_test = data[data["date"]>'2022-01-01']
    clf.fit(X_train[predictors], X_train["target"])
    preds = clf.predict(y_test[predictors])
    combined = pd.DataFrame(dict(actual=y_test["target"], predicted=preds), index=y_test.index)
    precision = precision_score(y_test["target"], preds)
    return combined, precision

# %%
combines, precision = make_predictions(games_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.48056537102473496

# %% [markdown]
# The precision was 0.48860759493670886 now the precision is 0.48056537102473496 a decrease of 0.00804222391197390

# %%
combined
# Out:
#        actual  prediction
# 178         0           0
# 179         0           1
# 180         0           0
# 181         1           1
# 182         0           1
# ...       ...         ...
# 17585       1           0
# 17586       1           0
# 17587       1           1
# 17588       0           1
# 17589       0           0
#
# [1580 rows x 2 columns]

# %%
combined = combined.merge(games_rolling[["date", "team", "team_opp", "won"]], left_index=True, right_index=True)

# %%
combined
# Out:
#        actual  prediction       date team team_opp    won
# 178         0           0 2017-09-12  ATL      ORL   True
# 179         0           1 2017-10-01  ATL      BRK   True
# 180         0           0 2017-10-02  ATL      SAC  False
# 181         1           1 2017-10-03  ATL      TOR   True
# 182         0           1 2017-10-11  ATL      DET  False
# ...       ...         ...        ...  ...      ...    ...
# 17585       1           0 2021-05-26  WAS      PHI  False
# 17586       1           0 2021-05-29  WAS      PHI  False
# 17587       1           1 2021-05-31  WAS      PHI   True
# 17588       0           1 2021-06-01  WAS      PHI  False
# 17589       0           0 2021-06-05  WAS      TOR   True
#
# [1580 rows x 6 columns]

# %%
#to make sure the names of the home and away team are the same 
#the Dataset already has the same names for home and away teams
#for future reference if names need to be normalised
class MissingDict(dict):
    __missing__ = lambda self, key: key
    
map_values = {
    
    "Golden State Warriors": "GSW",
    "Lakers": "LAL",
    "Boston Celtics": "BOS"
    
}
mapping = MissingDict(**map_values)

# %%
mapping["Golden State Warriors"]
# Out:
# 'GSW'

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#        actual  prediction       date team team_opp    won new_team
# 178         0           0 2017-09-12  ATL      ORL   True      ATL
# 179         0           1 2017-10-01  ATL      BRK   True      ATL
# 180         0           0 2017-10-02  ATL      SAC  False      ATL
# 181         1           1 2017-10-03  ATL      TOR   True      ATL
# 182         0           1 2017-10-11  ATL      DET  False      ATL
# ...       ...         ...        ...  ...      ...    ...      ...
# 17585       1           0 2021-05-26  WAS      PHI  False      WAS
# 17586       1           0 2021-05-29  WAS      PHI  False      WAS
# 17587       1           1 2021-05-31  WAS      PHI   True      WAS
# 17588       0           1 2021-06-01  WAS      PHI  False      WAS
# 17589       0           0 2021-06-05  WAS      TOR   True      WAS
#
# [1580 rows x 7 columns]

# %% [markdown]
# This makes sure that the predictions are the same on both sides

# %%
merged = combined.merge(combined, left_on=["date","new_team"], right_on=["date","team_opp"])

# %%
merged
# Out:
#      actual_x  prediction_x       date team_x team_opp_x  won_x new_team_x  \
# 0           1             1 2018-11-25    ATL        CHO   True        ATL
# 1           0             0 2018-11-28    ATL        CHO  False        ATL
# 2           0             0 2020-01-14    ATL        PHO   True        ATL
# 3           0             1 2020-01-26    ATL        WAS   True        ATL
# 4           0             1 2020-02-22    ATL        DAL   True        ATL
# ..        ...           ...        ...    ...        ...    ...        ...
# 157         0             0 2021-02-02    UTA        DET   True        UTA
# 158         1             0 2020-01-26    WAS        ATL  False        WAS
# 159         1             0 2020-01-30    WAS        CHO   True        WAS
# 160         1             1 2021-05-16    WAS        CHO   True        WAS
# 161         0             0 2021-06-05    WAS        TOR   True        WAS
#
#      actual_y  prediction_y team_y team_opp_y  won_y new_team_y
# ...

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# 0    20
# 1    15
# Name: actual_x, dtype: int64

# %%
15/20
# Out:
# 0.75

# %% [markdown]
# The accuracy is 75% from merging both sides of the match together
# Using more seasons could improve accuracy
# Using more columns in the data frame can improve accuracy
# Look at both current team and opponent team records for the season
